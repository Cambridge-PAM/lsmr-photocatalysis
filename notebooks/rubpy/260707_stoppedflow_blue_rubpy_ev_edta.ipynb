# %%
from stopflow import *

# stop flow with reaction in 50 ul chip with no film
# blue 455 nm irradiation at 10.4 mW for each time point, then uv-vis immediately after in the same chip
# flushed with fresh starting reaction mixture and repeated for new time point

# V(Ru(bpy)3, 12.5 mM, buffer) = 320 ul
# V(EV, 25 mM, buffer) = 960 ul
# V(EDTA, saturated, buffer) = 720 ul

t = [t*30 for t in range(1, 15)] # residence times in seconds for 1-7 minutes in 30s intervals
c0 = solprop(cstock=25e-3, valiquot=960e-6, vsol=2e-3) # initial EV2+ concentration
film = 'blank PVAc'
light = 'blue'
wavelength = 455e-9 # m
power = 10.4e-3 # W
x = 'E'

data = f'./results/260707_Rubpy_EV_EDTA_StopFlow/'
concvstimeplot(data, t, c0, x, film, light, wavelength, power, i=9)
lncvstimeplot(data, t, c0, x, film, light, wavelength, power, i=9)
spectrumvstimeplot(data, t, c0, x, film, light, wavelength, power)
