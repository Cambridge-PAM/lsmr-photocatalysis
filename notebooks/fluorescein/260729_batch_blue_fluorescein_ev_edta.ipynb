# %%
from batch import *

# V(fluorescein, 5 mM, buffer) = 18 ul,
# V(EV, 30 mM, buffer) depending on fluorescein mol%
# V(EDTA, 25 mM, buffer) 1.5 eq of EV
# made up to 3 ml pH 7 buffer
# blue light 455 nm irradiation

x = 'E'
duration = 15*60 # 15 min
root = f"./results/260729_Fluorescein_{x}V_EDTA_Batch/Fluorescein_{x}V_EDTA_Batch_"

# (mol% fluorescein, start times) for each run, start time adjusted slightly to begin at linear region
runs = [(1, "11-10-00-000"), # 11-10-00-000 recorded start time
        (2, "11-30-00-000"), # 11-30-00-000
        (3, "11-50-00-000"), # 11-50-00-000
        (4, "12-14-00-000"), # 12-14-00-000
        (5, "12-35-00-000")] # 12-35-00-000

for (p, start) in runs:
    data = f'{root}{p}'
    c0 = (100/p)*0.03e-3 # initial concentration of EV, back-calculated from mol% of PC
    concvstimeplot(data, c0, start, x, duration=duration, new=True,
                   istart=200, r2threshold=0.99, interceptthreshold=1e-6)

# for (p, start) in runs:
#     data = f'{root}{p}'
#     c0 = (100/p)*0.03e-3 # initial concentration of EV, back-calculated from mol% of PC
#     lncvstimeplot(data, c0, start, x, duration=duration, new=True,
#                   istart=100, r2threshold=0.99, interceptthreshold=np.log(c0))

for (p, start) in runs:
    data = f'{root}{p}'
    c0 = (100/p)*0.03e-3 # initial concentration of EV, back-calculated from mol% of PC
    spectrumvstimeplot(data, c0, start, x, duration=duration, new=True, vmin=0, vmax=0.1)

spectrumvsconcplot(root, runs, x, t=5*60, new=True, setzero=False)
